# %%
#Import pandas, matplotlib.pyplot, and seaborn in the correct lines below
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import datetime
#from datetime import datetime

from library.sb_utils import save_file

# %%
# load the covid data for each county from https://www.kaggle.com/datasets/fireballbyedimyrnmom/us-counties-covid-19-dataset?resource=download
county_data = pd.read_csv('../data/us-counties.csv')

# %%
# Call info to get a summary of the data
county_data = county_data.fillna(0)
county_data['deaths'] = county_data['deaths'].astype(int)
county_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2502832 entries, 0 to 2502831
# Data columns (total 6 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    object
#  1   county  object
#  2   state   object
#  3   fips    float64
#  4   cases   int64
#  5   deaths  int32
# dtypes: float64(1), int32(1), int64(1), object(3)
# memory usage: 105.0+ MB

# %% [markdown]
# `fips` refers to the fips county code. `cases` and `deaths` refers to the total number of cases / deaths total in each county (not for each day but a running total).

# %%
# Call head to get first few rows of data
county_data.head()
# Out:
#          date     county       state     fips  cases  deaths
# 0  2020-01-21  Snohomish  Washington  53061.0      1       0
# 1  2020-01-22  Snohomish  Washington  53061.0      1       0
# 2  2020-01-23  Snohomish  Washington  53061.0      1       0
# 3  2020-01-24       Cook    Illinois  17031.0      1       0
# 4  2020-01-24  Snohomish  Washington  53061.0      1       0

# %% [markdown]
# We can see that the our data is sorted by date order as Washington State had the first reported case of COVID-19 in the United States. We can also see that data begins recording for a specific county once they record their first COVID-19 case.

# %% [markdown]
# Looking at our other data source, we will not be using the fips county code. So we will drop the column.

# %%
#Drop the 'fips' column from county_data. Use inplace=True
county_data.drop(columns='fips', inplace=True)
county_data.head()
# Out:
#          date     county       state  cases  deaths
# 0  2020-01-21  Snohomish  Washington      1       0
# 1  2020-01-22  Snohomish  Washington      1       0
# 2  2020-01-23  Snohomish  Washington      1       0
# 3  2020-01-24       Cook    Illinois      1       0
# 4  2020-01-24  Snohomish  Washington      1       0

# %% [markdown]
# Count the number of missing values in each column and sort them.

# %%
#Count (using `.sum()`) the number of missing values (`.isnull()`) in each column of 
#ski_data as well as the percentages (using `.mean()` instead of `.sum()`).
#Order them (increasing or decreasing) using sort_values
#Call `pd.concat` to present these in a single table (DataFrame) with the helpful column names 'count' and '%'
missing = pd.concat([county_data.isnull().sum(), 100 * county_data.isnull().mean()], axis=1)
missing.columns=['Count', '%']
missing.sort_values(by='Count', ascending=False)
# Out:
#         Count    %
# date        0  0.0
# county      0  0.0
# state       0  0.0
# cases       0  0.0
# deaths      0  0.0

# %% [markdown]
# This is good for our dataset as we see that we have no NaN values listed.

# %% [markdown]
# We now need to investigate counties with invalid names (Unkown).

# %%
#Remove rows with Unknown County Name
indexName = county_data[county_data['county'] == 'Unknown'].index
county_data.drop(indexName , inplace=True)
county_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2481431 entries, 0 to 2502831
# Data columns (total 5 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    object
#  1   county  object
#  2   state   object
#  3   cases   int64
#  4   deaths  int32
# dtypes: int32(1), int64(1), object(3)
# memory usage: 104.1+ MB

# %% [markdown]
# We can see that our row total has dropped a significant amount since removing counties with an unknown name.

# %% [markdown]
# Do we want to keep county information from all states?

# %%
county_data['state'].value_counts()
# Out:
# Texas                       193498
# Georgia                     124105
# Virginia                    103089
# Kentucky                     92530
# Missouri                     89562
# Kansas                       79048
# Illinois                     78835
# North Carolina               77808
# Iowa                         76327
# Tennessee                    74008
# Indiana                      71881
# Nebraska                     68736
# Ohio                         68662
# Minnesota                    67104
# Michigan                     64424
# Mississippi                  64079
# Oklahoma                     59283
# Arkansas                     58247
# Puerto Rico                  57605
# Wisconsin                    55858
# Florida                      52590
# Pennsylvania                 52439
# Alabama                      52312
# Louisiana                    50116
# South Dakota                 49547
# Colorado                     49463
# New York                     45682
# California                   45676
# West Virginia                42234
# Montana                      40654
# North Dakota                 39782
# South Carolina               36088
# Idaho                        33172
# Washington                   30713
# Oregon                       27777
# New Mexico                   25281
# Utah                         22144
# Alaska                       19865
# Maryland                     18884
# Wyoming                      17811
# New Jersey                   16624
# Nevada                       12750
# Maine                        12498
# Arizona                      11835
# Massachusetts                11125
# Vermont                      10976
# New Hampshire                 7877
# Connecticut                   6316
# Rhode Island                  3900
# Hawaii                        3688
# Delaware                      2369
# Virgin Islands                2304
# Northern Mariana Islands      1452
# District of Columbia           798
# Name: state, dtype: int64

# %% [markdown]
# We want to remove the states not officially apart of the United States except District of Columbia.
#
# These states include Northern Mariana Islands, Virgin Islands, and Puerto Rico

# %%
#Remove rows with NMI, VI, and PR
indexState = county_data[(county_data['state'] == 'Northern Mariana Islands') | (county_data['state'] == 'Virgin Islands')
                         | (county_data['state'] == 'Puerto Rico')].index
county_data.drop(indexState , inplace=True)
county_data['state'].value_counts()
# Out:
# Texas                   193498
# Georgia                 124105
# Virginia                103089
# Kentucky                 92530
# Missouri                 89562
# Kansas                   79048
# Illinois                 78835
# North Carolina           77808
# Iowa                     76327
# Tennessee                74008
# Indiana                  71881
# Nebraska                 68736
# Ohio                     68662
# Minnesota                67104
# Michigan                 64424
# Mississippi              64079
# Oklahoma                 59283
# Arkansas                 58247
# Wisconsin                55858
# Florida                  52590
# Pennsylvania             52439
# Alabama                  52312
# Louisiana                50116
# South Dakota             49547
# Colorado                 49463
# New York                 45682
# California               45676
# West Virginia            42234
# Montana                  40654
# North Dakota             39782
# South Carolina           36088
# Idaho                    33172
# Washington               30713
# Oregon                   27777
# New Mexico               25281
# Utah                     22144
# Alaska                   19865
# Maryland                 18884
# Wyoming                  17811
# New Jersey               16624
# Nevada                   12750
# Maine                    12498
# Arizona                  11835
# Massachusetts            11125
# Vermont                  10976
# New Hampshire             7877
# Connecticut               6316
# Rhode Island              3900
# Hawaii                    3688
# Delaware                  2369
# District of Columbia       798
# Name: state, dtype: int64

# %%
#the number of unique values in each
county_data[['county', 'state']].nunique()
# Out:
# county    1850
# state       51
# dtype: int64

# %% [markdown]
# We now have 51 states/areas of the US

# %% [markdown]
# We want to now add two columns to represent the change every day of covid cases as well as deaths

# %%
# add new column for change in cases and deaths per day
county_data['date'] = pd.to_datetime(county_data['date'], format="%Y-%m-%d")
groupdf = county_data.groupby('date')

def add(row):
    newdate = row['date'] - datetime.timedelta(days=1)
    try:
        datedf = groupdf.get_group(newdate)
        prev = datedf.loc[(datedf['county'] == row['county']) & (datedf['state'] == row['state'])]
        row['cases_change'] = row['cases'] - int(prev['cases'])
        row['deaths_change'] = row['deaths'] - int(prev['deaths'])
        return row
    except:
        row['cases_change'] = 0
        row['deaths_change'] = 0
        return row

county_data = county_data.apply(add, axis=1)
county_data.head()
# Out:
#         date     county       state  cases  deaths  cases_change  \
# 0 2020-01-21  Snohomish  Washington      1       0             0
# 1 2020-01-22  Snohomish  Washington      1       0             0
# 2 2020-01-23  Snohomish  Washington      1       0             0
# 3 2020-01-24       Cook    Illinois      1       0             0
# 4 2020-01-24  Snohomish  Washington      1       0             0
#
#    deaths_change
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
# Now lets work with our other data sources taken from https://www.ers.usda.gov/data-products/county-level-data-sets/county-level-data-sets-download-data/
# the supplied CSV data file is the data directory
# demographics taken from https://data.census.gov/table?q=P6&t=Race+and+Ethnicity&g=010XX00US$0500000&y=2020&tid=DECENNIALDHC2020.P6
education = pd.read_csv('../data/education.csv')
population = pd.read_csv('../data/population_estimates.csv')
poverty = pd.read_csv('../data/poverty_estimates.csv')
demographics = pd.read_csv('../data/demographics.csv')

# %%
# Call info to get a summary of the data
education.info()
population.info()
poverty.info()
demographics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3285 entries, 0 to 3284
# Data columns (total 55 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Federal Information Processing Standard (FIPS) Code                       3285 non-null   int64
#  1   State                                                                     3285 non-null   object
#  2   Area name                                                                 3285 non-null   object
#  3   2003 Rural-urban Continuum Code                                           3221 non-null   float64
#  4   2003 Urban Influence Code                                                 3221 non-null   float64
#  5   2013 Rural-urban Continuum Code                                           3221 non-null   float64
#  6   2013 Urban Influence Code                                                 3221 non-null   float64
#  7   Less than a high school diploma, 1970                                     3186 non-null   object
#  8   High school diploma only, 1970                                            3186 non-null   object
#  9   Some college (1-3 years), 1970                                            3186 non-null   object
#  10  Four years of college or higher, 1970                                     3186 non-null   object
#  11  Percent of adults with less than a high school diploma, 1970              3186 non-null   float64
#  12  Percent of adults with a high school diploma only, 1970                   3186 non-null   float64
#  13  Percent of adults completing some college (1-3 years), 1970               3186 non-null   float64
#  14  Percent of adults completing four years of college or higher, 1970        3186 non-null   float64
#  15  Less than a high school diploma, 1980                                     3267 non-null   object
#  16  High school diploma only, 1980                                            3267 non-null   object
#  17  Some college (1-3 years), 1980                                            3267 non-null   object
#  18  Four years of college or higher, 1980                                     3267 non-null   object
#  19  Percent of adults with less than a high school diploma, 1980              3267 non-null   float64
#  20  Percent of adults with a high school diploma only, 1980                   3267 non-null   float64
#  21  Percent of adults completing some college (1-3 years), 1980               3267 non-null   float64
#  22  Percent of adults completing four years of college or higher, 1980        3267 non-null   float64
#  23  Less than a high school diploma, 1990                                     3271 non-null   object
#  24  High school diploma only, 1990                                            3271 non-null   object
#  25  Some college or associate's degree, 1990                                  3271 non-null   object
#  26  Bachelor's degree or higher, 1990                                         3271 non-null   object
#  27  Percent of adults with less than a high school diploma, 1990              3271 non-null   float64
#  28  Percent of adults with a high school diploma only, 1990                   3271 non-null   float64
#  29  Percent of adults completing some college or associate's degree, 1990     3270 non-null   float64
#  30  Percent of adults with a bachelor's degree or higher, 1990                3271 non-null   float64
#  31  Less than a high school diploma, 2000                                     3272 non-null   object
#  32  High school diploma only, 2000                                            3272 non-null   object
#  33  Some college or associate's degree, 2000                                  3272 non-null   object
#  34  Bachelor's degree or higher, 2000                                         3272 non-null   object
#  35  Percent of adults with less than a high school diploma, 2000              3272 non-null   float64
#  36  Percent of adults with a high school diploma only, 2000                   3272 non-null   float64
#  37  Percent of adults completing some college or associate's degree, 2000     3272 non-null   float64
#  38  Percent of adults with a bachelor's degree or higher, 2000                3272 non-null   float64
#  39  Less than a high school diploma, 2008-12                                  3274 non-null   object
#  40  High school diploma only, 2008-12                                         3274 non-null   object
#  41  Some college or associate's degree, 2008-12                               3274 non-null   object
#  42  Bachelor's degree or higher, 2008-12                                      3274 non-null   object
#  43  Percent of adults with less than a high school diploma, 2008-12           3274 non-null   float64
#  44  Percent of adults with a high school diploma only, 2008-12                3274 non-null   float64
#  45  Percent of adults completing some college or associate's degree, 2008-12  3274 non-null   float64
#  46  Percent of adults with a bachelor's degree or higher, 2008-12             3274 non-null   float64
#  47  Less than a high school diploma, 2017-21                                  3274 non-null   object
#  48  High school diploma only, 2017-21                                         3274 non-null   object
#  49  Some college or associate's degree, 2017-21                               3273 non-null   object
#  50  Bachelor's degree or higher, 2017-21                                      3273 non-null   object
#  51  Percent of adults with less than a high school diploma, 2017-21           3274 non-null   float64
#  52  Percent of adults with a high school diploma only, 2017-21                3274 non-null   float64
#  53  Percent of adults completing some college or associate's degree, 2017-21  3274 non-null   float64
#  54  Percent of adults with a bachelor's degree or higher, 2017-21             3274 non-null   float64
# dtypes: float64(28), int64(1), object(26)
# memory usage: 1.4+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3283 entries, 0 to 3282
# Data columns (total 53 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   FIPStxt                          3283 non-null   int64
#  1   State                            3283 non-null   object
#  2   Area_Name                        3283 non-null   object
#  3   Rural_Urban_Continuum_Code_2003  3214 non-null   float64
#  4   Rural_Urban_Continuum_Code_2013  3219 non-null   float64
#  5   Urban_Influence_2003             3136 non-null   float64
#  6   Urban_Influence_2013             3219 non-null   float64
#  7   Economic_typology_2015           3141 non-null   float64
#  8   CENSUS_2020_POP                  3274 non-null   object
#  9   ESTIMATES_BASE_2020              3275 non-null   object
#  10  POP_ESTIMATE_2020                3275 non-null   object
#  11  POP_ESTIMATE_2021                3275 non-null   object
#  12  POP_ESTIMATE_2022                3275 non-null   object
#  13  N_POP_CHG_2020                   3196 non-null   object
#  14  N_POP_CHG_2021                   3196 non-null   object
#  15  N_POP_CHG_2022                   3196 non-null   object
#  16  BIRTHS_2020                      3196 non-null   object
#  17  BIRTHS_2021                      3196 non-null   object
#  18  BIRTHS_2022                      3196 non-null   object
#  19  DEATHS_2020                      3196 non-null   object
#  20  DEATHS_2021                      3196 non-null   object
#  21  DEATHS_2022                      3196 non-null   object
#  22  NATURAL_CHG_2020                 3196 non-null   object
#  23  NATURAL_CHG_2021                 3196 non-null   object
#  24  NATURAL_CHG_2022                 3196 non-null   object
#  25  INTERNATIONAL_MIG_2020           3196 non-null   object
#  26  INTERNATIONAL_MIG_2021           3196 non-null   object
#  27  INTERNATIONAL_MIG_2022           3196 non-null   object
#  28  DOMESTIC_MIG_2020                3196 non-null   object
#  29  DOMESTIC_MIG_2021                3196 non-null   object
#  30  DOMESTIC_MIG_2022                3196 non-null   object
#  31  NET_MIG_2020                     3196 non-null   object
#  32  NET_MIG_2021                     3196 non-null   object
#  33  NET_MIG_2022                     3196 non-null   object
#  34  RESIDUAL_2020                    3196 non-null   object
#  35  RESIDUAL_2021                    3196 non-null   object
#  36  RESIDUAL_2022                    3196 non-null   object
#  37  GQ_ESTIMATES_BASE_2020           3195 non-null   object
#  38  GQ_ESTIMATES_2020                3195 non-null   object
#  39  GQ_ESTIMATES_2021                3195 non-null   object
#  40  GQ_ESTIMATES_2022                3195 non-null   float64
#  41  R_BIRTH_2021                     3196 non-null   float64
#  42  R_BIRTH_2022                     3196 non-null   float64
#  43  R_DEATH_2021                     3196 non-null   float64
#  44  R_DEATH_2022                     3196 non-null   float64
#  45  R_NATURAL_CHG_2021               3196 non-null   float64
#  46  R_NATURAL_CHG_2022               3196 non-null   float64
#  47  R_INTERNATIONAL_MIG_2021         3196 non-null   float64
#  48  R_INTERNATIONAL_MIG_2022         3196 non-null   float64
#  49  R_DOMESTIC_MIG_2021              3196 non-null   float64
#  50  R_DOMESTIC_MIG_2022              3196 non-null   float64
#  51  R_NET_MIG_2021                   3196 non-null   float64
#  52  R_NET_MIG_2022                   3196 non-null   float64
# dtypes: float64(18), int64(1), object(34)
# memory usage: 1.3+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3195 entries, 0 to 3194
# Data columns (total 34 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   FIPS_Code                        3195 non-null   int64
#  1   State                            3195 non-null   object
#  2   Area_name                        3195 non-null   object
#  3   Rural-urban_Continuum_Code_2003  3136 non-null   float64
#  4   Urban_Influence_Code_2003        3136 non-null   float64
#  5   Rural-urban_Continuum_Code_2013  3141 non-null   float64
#  6   Urban_Influence_Code_ 2013       3141 non-null   float64
#  7   POVALL_2021                      3194 non-null   float64
#  8   CI90LBALL_2021                   3194 non-null   float64
#  9   CI90UBALL_2021                   3194 non-null   float64
#  10  PCTPOVALL_2021                   3194 non-null   float64
#  11  CI90LBALLP_2021                  3194 non-null   float64
#  12  CI90UBALLP_2021                  3194 non-null   float64
#  13  POV017_2021                      3194 non-null   float64
#  14  CI90LB017_2021                   3194 non-null   float64
#  15  CI90UB017_2021                   3194 non-null   float64
#  16  PCTPOV017_2021                   3194 non-null   float64
#  17  CI90LB017P_2021                  3194 non-null   float64
#  18  CI90UB017P_2021                  3194 non-null   float64
#  19  POV517_2021                      3194 non-null   float64
#  20  CI90LB517_2021                   3194 non-null   float64
#  21  CI90UB517_2021                   3194 non-null   float64
#  22  PCTPOV517_2021                   3194 non-null   float64
#  23  CI90LB517P_2021                  3194 non-null   float64
#  24  CI90UB517P_2021                  3194 non-null   float64
#  25  MEDHHINC_2021                    3194 non-null   float64
#  26  CI90LBINC_2021                   3194 non-null   float64
#  27  CI90UBINC_2021                   3194 non-null   float64
#  28  POV04_2021                       52 non-null     float64
#  29  CI90LB04_2021                    52 non-null     float64
#  30  CI90UB04_2021                    52 non-null     float64
#  31  PCTPOV04_2021                    52 non-null     float64
#  32  CI90LB04P_2021                   52 non-null     float64
#  33  CI90UB04P_2021                   52 non-null     float64
# dtypes: float64(31), int64(1), object(2)
# memory usage: 848.8+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3222 entries, 0 to 3221
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   GEO_ID       3222 non-null   object
#  1   NAME         3222 non-null   object
#  2   P6_001N      3222 non-null   object
#  3   P6_001NA     1 non-null      object
#  4   P6_002N      3222 non-null   object
#  5   P6_002NA     1 non-null      object
#  6   P6_003N      3222 non-null   object
#  7   P6_003NA     1 non-null      object
#  8   P6_004N      3222 non-null   object
#  9   P6_004NA     1 non-null      object
#  10  P6_005N      3222 non-null   object
#  11  P6_005NA     1 non-null      object
#  12  P6_006N      3222 non-null   object
#  13  P6_006NA     1 non-null      object
#  14  P6_007N      3222 non-null   object
#  15  P6_007NA     1 non-null      object
#  16  Unnamed: 16  0 non-null      float64
# dtypes: float64(1), object(16)
# memory usage: 428.0+ KB

# %%
education.head()
# Out:
#    Federal Information Processing Standard (FIPS) Code State       Area name  \
# 0                                                  0      US   United States
# 1                                               1000      AL         Alabama
# 2                                               1001      AL  Autauga County
# 3                                               1003      AL  Baldwin County
# 4                                               1005      AL  Barbour County
#
#    2003 Rural-urban Continuum Code  2003 Urban Influence Code  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              2.0                        2.0
# 3                              4.0                        5.0
# 4                              6.0                        6.0
#
#    2013 Rural-urban Continuum Code  2013 Urban Influence Code  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              2.0                        2.0
# 3                              3.0                        2.0
# 4                              6.0                        6.0
#
#   Less than a high school diploma, 1970 High school diploma only, 1970  \
# 0                            52,373,312                     34,158,051
# 1                             1,062,306                        468,269
# 2                                 6,611                          3,757
# 3                                18,726                          8,426
# 4                                 8,120                          2,242
#
#   Some college (1-3 years), 1970  ...  \
# 0                     11,650,730  ...
# 1                        136,287  ...
# 2                            933  ...
# 3                          2,334  ...
# 4                            581  ...
#
#   Percent of adults completing some college or associate's degree, 2008-12  \
# 0                                               29.0
# 1                                               29.0
# 2                                               29.6
# 3                                               31.8
# 4                                               25.8
#
#    Percent of adults with a bachelor's degree or higher, 2008-12  \
# 0                                               28.5
# 1                                               22.3
# 2                                               21.7
# 3                                               27.7
# 4                                               14.5
#
#    Less than a high school diploma, 2017-21  \
# 0                                25,050,356
# 1                                   430,047
# 2                                     4,126
# 3                                    14,555
# 4                                     4,378
#
#    High school diploma only, 2017-21  \
# 0                         59,636,386
# 1                          1,041,209
# 2                             12,977
# 3                             44,342
# 4                              6,600
#
#    Some college or associate's degree, 2017-21  \
# 0                                   64,656,741
# 1                                    1,032,122
# 2                                       11,367
# 3                                       50,518
# 4                                        5,010
#
#   Bachelor's degree or higher, 2017-21  \
# 0                           75,808,834
# 1                              910,425
# 2                               11,144
# 3                               52,562
# 4                                2,007
#
#   Percent of adults with less than a high school diploma, 2017-21  \
# 0                                               11.1
# 1                                               12.6
# 2                                               10.4
# 3                                                9.0
# 4                                               24.3
#
#   Percent of adults with a high school diploma only, 2017-21  \
# 0                                               26.5
# 1                                               30.5
# 2                                               32.8
# 3                                               27.4
# 4                                               36.7
#
#   Percent of adults completing some college or associate's degree, 2017-21  \
# 0                                               28.7
# 1                                               30.2
# 2                                               28.7
# 3                                               31.2
# 4                                               27.8
#
#    Percent of adults with a bachelor's degree or higher, 2017-21
# 0                                               33.7
# 1                                               26.7
# 2                                               28.1
# 3                                               32.5
# 4                                               11.2
#
# [5 rows x 55 columns]

# %%
population.head()
# Out:
#    FIPStxt State       Area_Name  Rural_Urban_Continuum_Code_2003  \
# 0        0    US   United States                              NaN
# 1     1000    AL         Alabama                              NaN
# 2     1001    AL  Autauga County                              2.0
# 3     1003    AL  Baldwin County                              4.0
# 4     1005    AL  Barbour County                              6.0
#
#    Rural_Urban_Continuum_Code_2013  Urban_Influence_2003  \
# 0                              NaN                   NaN
# 1                              NaN                   NaN
# 2                              2.0                   2.0
# 3                              3.0                   5.0
# 4                              6.0                   6.0
#
#    Urban_Influence_2013  Economic_typology_2015 CENSUS_2020_POP  \
# 0                   NaN                     NaN     331,449,281
# 1                   NaN                     NaN       5,024,279
# 2                   2.0                     0.0          58,805
# 3                   2.0                     5.0         231,767
# 4                   6.0                     3.0          25,223
#
#   ESTIMATES_BASE_2020  ... R_DEATH_2021 R_DEATH_2022 R_NATURAL_CHG_2021  \
# 0         331,449,520  ...         10.4         10.4                0.4
# 1           5,024,356  ...         13.7         13.2               -2.4
# 2              58,802  ...         11.5         11.3                0.2
# 3             231,761  ...         12.9         12.0               -2.9
# 4              25,224  ...         15.5         15.1               -4.3
#
#   R_NATURAL_CHG_2022 R_INTERNATIONAL_MIG_2021 R_INTERNATIONAL_MIG_2022  \
# 0                0.7                      1.1                      3.0
# 1               -1.7                      0.4                      0.9
# 2                0.6                      0.3                      0.5
# 3               -2.1                      0.4                      1.3
# 4               -3.9                      0.0                      0.2
#
#   R_DOMESTIC_MIG_2021 R_DOMESTIC_MIG_2022 R_NET_MIG_2021 R_NET_MIG_2022
# 0                 0.0                 0.0            1.1            3.0
# 1                 5.5                 5.7            5.9            6.6
# 2                 4.1                 8.5            4.3            9.0
# 3                29.5                28.7           29.9           30.0
# 4               -12.4                 9.9          -12.4           10.0
#
# [5 rows x 53 columns]

# %%
poverty.head()
# Out:
#    FIPS_Code State       Area_name  Rural-urban_Continuum_Code_2003  \
# 0          0    US   United States                              NaN
# 1       1000    AL         Alabama                              NaN
# 2       1001    AL  Autauga County                              2.0
# 3       1003    AL  Baldwin County                              4.0
# 4       1005    AL  Barbour County                              6.0
#
#    Urban_Influence_Code_2003  Rural-urban_Continuum_Code_2013  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
#
#    Urban_Influence_Code_ 2013  POVALL_2021  CI90LBALL_2021  CI90UBALL_2021  \
# 0                         NaN   41393176.0      41149497.0      41636855.0
# 1                         NaN     800848.0        782169.0        819527.0
# 2                         2.0       6296.0          4772.0          7820.0
# 3                         2.0      25526.0         21599.0         29453.0
# 4                         6.0       5089.0          3773.0          6405.0
#
#    ...  CI90UB517P_2021  MEDHHINC_2021  CI90LBINC_2021  CI90UBINC_2021  \
# 0  ...             16.3        69717.0         69583.0         69851.0
# 1  ...             22.5        53990.0         53218.0         54762.0
# 2  ...             20.4        66444.0         60061.0         72827.0
# 3  ...             18.5        65658.0         60723.0         70593.0
# 4  ...             44.6        38649.0         34308.0         42990.0
#
#    POV04_2021  CI90LB04_2021  CI90UB04_2021  PCTPOV04_2021  CI90LB04P_2021  \
# 0   3349149.0      3299669.0      3398629.0           18.3            18.0
# 1     71220.0        66888.0        75552.0           25.1            23.6
# 2         NaN            NaN            NaN            NaN             NaN
# 3         NaN            NaN            NaN            NaN             NaN
# 4         NaN            NaN            NaN            NaN             NaN
#
#    CI90UB04P_2021
# 0            18.6
# 1            26.6
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# Lets first remove the unwanted rows (State Total Rows) as well as filter out the columns we want for education

# %%
education.dropna(subset = ['2003 Rural-urban Continuum Code'], inplace=True)
education = education[['State','Area name','Less than a high school diploma, 2017-21',
                       'High school diploma only, 2017-21', 'Some college or associate\'s degree, 2017-21',
                       'Bachelor\'s degree or higher, 2017-21',
                       'Percent of adults with less than a high school diploma, 2017-21',
                       'Percent of adults with a high school diploma only, 2017-21',
                       'Percent of adults completing some college or associate\'s degree, 2017-21',
                       'Percent of adults with a bachelor\'s degree or higher, 2017-21']]
# Drop PR State data
education = education[education['State'] != 'PR']
education
# Out:
#      State          Area name Less than a high school diploma, 2017-21  \
# 2       AL     Autauga County                                    4,126
# 3       AL     Baldwin County                                   14,555
# 4       AL     Barbour County                                    4,378
# 5       AL        Bibb County                                    3,125
# 6       AL      Blount County                                    6,650
# ...    ...                ...                                      ...
# 3201    WY  Sweetwater County                                    2,029
# 3202    WY       Teton County                                      701
# 3203    WY       Uinta County                                      851
# 3204    WY    Washakie County                                      320
# 3205    WY      Weston County                                      348
#
#      High school diploma only, 2017-21  \
# 2                               12,977
# 3                               44,342
# 4                                6,600
# 5                                7,052
# 6                               14,284
# ...                                ...
# 3201                             9,069
# 3202                             2,984
# 3203                             4,820
# 3204                             1,391
# 3205                             1,826
#
#      Some college or associate's degree, 2017-21  \
# 2                                         11,367
# 3                                         50,518
# 4                                          5,010
# 5                                          3,967
# 6                                         13,673
# ...                                          ...
# 3201                                      11,324
# 3202                                       3,755
# 3203                                       5,186
# 3204                                       2,293
# 3205                                       1,818
#
#      Bachelor's degree or higher, 2017-21  \
# 2                                  11,144
# 3                                  52,562
# 4                                   2,007
# 5                                   1,913
# 6                                   6,061
# ...                                   ...
# 3201                                5,394
# 3202                               10,219
# 3203                                2,376
# 3204                                1,419
# 3205                                  900
#
#       Percent of adults with less than a high school diploma, 2017-21  \
# 2                                                  10.4
# 3                                                   9.0
# 4                                                  24.3
# 5                                                  19.5
# 6                                                  16.4
# ...                                                 ...
# 3201                                                7.3
# 3202                                                4.0
# 3203                                                6.4
# 3204                                                5.9
# 3205                                                7.1
#
#       Percent of adults with a high school diploma only, 2017-21  \
# 2                                                  32.8
# 3                                                  27.4
# 4                                                  36.7
# 5                                                  43.9
# 6                                                  35.1
# ...                                                 ...
# 3201                                               32.6
# 3202                                               16.9
# 3203                                               36.4
# 3204                                               25.7
# 3205                                               37.3
#
#       Percent of adults completing some college or associate's degree, 2017-21  \
# 2                                                  28.7
# 3                                                  31.2
# 4                                                  27.8
# 5                                                  24.7
# 6                                                  33.6
# ...                                                 ...
# 3201                                               40.7
# 3202                                               21.3
# 3203                                               39.2
# 3204                                               42.3
# 3205                                               37.2
#
#       Percent of adults with a bachelor's degree or higher, 2017-21
# 2                                                  28.1
# 3                                                  32.5
# 4                                                  11.2
# 5                                                  11.9
# 6                                                  14.9
# ...                                                 ...
# 3201                                               19.4
# 3202                                               57.9
# 3203                                               18.0
# 3204                                               26.2
# 3205                                               18.4
#
# [3143 rows x 10 columns]

# %%
education.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3143 entries, 2 to 3205
# Data columns (total 10 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   State                                                                     3143 non-null   object
#  1   Area name                                                                 3143 non-null   object
#  2   Less than a high school diploma, 2017-21                                  3136 non-null   object
#  3   High school diploma only, 2017-21                                         3136 non-null   object
#  4   Some college or associate's degree, 2017-21                               3135 non-null   object
#  5   Bachelor's degree or higher, 2017-21                                      3135 non-null   object
#  6   Percent of adults with less than a high school diploma, 2017-21           3136 non-null   float64
#  7   Percent of adults with a high school diploma only, 2017-21                3136 non-null   float64
#  8   Percent of adults completing some college or associate's degree, 2017-21  3136 non-null   float64
#  9   Percent of adults with a bachelor's degree or higher, 2017-21             3136 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 270.1+ KB

# %% [markdown]
# Lets now check out for any NaN rows

# %%
education[education.isna().any(axis=1)]
# Out:
#      State                                    Area name  \
# 96      AK  Prince of Wales-Outer Ketchikan Census Area
# 100     AK            Skagway-Hoonah-Angoon Census Area
# 103     AK                   Valdez-Cordova Census Area
# 105     AK              Wrangell-Petersburg Census Area
# 1691    MT                    Yellowstone National Park
# 2708    TX                                Kenedy County
# 2728    TX                                Loving County
# 2974    VA                                 Bedford city
# 2979    VA                           Clifton Forge city
#
#      Less than a high school diploma, 2017-21  \
# 96                                        NaN
# 100                                       NaN
# 103                                       NaN
# 105                                       NaN
# 1691                                      NaN
# 2708                                       84
# 2728                                        3
# 2974                                      NaN
# 2979                                      NaN
#
#      High school diploma only, 2017-21  \
# 96                                 NaN
# 100                                NaN
# 103                                NaN
# 105                                NaN
# 1691                               NaN
# 2708                                15
# 2728                                 9
# 2974                               NaN
# 2979                               NaN
#
#      Some college or associate's degree, 2017-21  \
# 96                                           NaN
# 100                                          NaN
# 103                                          NaN
# 105                                          NaN
# 1691                                         NaN
# 2708                                         NaN
# 2728                                          40
# 2974                                         NaN
# 2979                                         NaN
#
#      Bachelor's degree or higher, 2017-21  \
# 96                                    NaN
# 100                                   NaN
# 103                                   NaN
# 105                                   NaN
# 1691                                  NaN
# 2708                                    4
# 2728                                  NaN
# 2974                                  NaN
# 2979                                  NaN
#
#       Percent of adults with less than a high school diploma, 2017-21  \
# 96                                                  NaN
# 100                                                 NaN
# 103                                                 NaN
# 105                                                 NaN
# 1691                                                NaN
# 2708                                               81.6
# 2728                                                5.8
# 2974                                                NaN
# 2979                                                NaN
#
#       Percent of adults with a high school diploma only, 2017-21  \
# 96                                                  NaN
# 100                                                 NaN
# 103                                                 NaN
# 105                                                 NaN
# 1691                                                NaN
# 2708                                               14.6
# 2728                                               17.3
# 2974                                                NaN
# 2979                                                NaN
#
#       Percent of adults completing some college or associate's degree, 2017-21  \
# 96                                                  NaN
# 100                                                 NaN
# 103                                                 NaN
# 105                                                 NaN
# 1691                                                NaN
# 2708                                                0.0
# 2728                                               76.9
# 2974                                                NaN
# 2979                                                NaN
#
#       Percent of adults with a bachelor's degree or higher, 2017-21
# 96                                                  NaN
# 100                                                 NaN
# 103                                                 NaN
# 105                                                 NaN
# 1691                                                NaN
# 2708                                                3.9
# 2728                                                0.0
# 2974                                                NaN
# 2979                                                NaN

# %%
# Drop the rows with NaN entirely
education = education.dropna()
education[education.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [State, Area name, Less than a high school diploma, 2017-21, High school diploma only, 2017-21, Some college or associate's degree, 2017-21, Bachelor's degree or higher, 2017-21, Percent of adults with less than a high school diploma, 2017-21, Percent of adults with a high school diploma only, 2017-21, Percent of adults completing some college or associate's degree, 2017-21, Percent of adults with a bachelor's degree or higher, 2017-21]
# Index: []

# %% [markdown]
# Now lets work with the population df

# %%
population.dropna(subset = ['Rural_Urban_Continuum_Code_2003'], inplace=True)
population = population[['State','Area_Name','POP_ESTIMATE_2020', 'POP_ESTIMATE_2021', 'POP_ESTIMATE_2022']]
# Drop PR State data
population = population[population['State'] != 'PR']
population
# Out:
#      State          Area_Name POP_ESTIMATE_2020 POP_ESTIMATE_2021  \
# 2       AL     Autauga County            58,902            59,210
# 3       AL     Baldwin County           233,219           239,361
# 4       AL     Barbour County            24,960            24,539
# 5       AL        Bibb County            22,183            22,370
# 6       AL      Blount County            59,102            59,085
# ...    ...                ...               ...               ...
# 3199    WY  Sweetwater County            42,190            41,582
# 3200    WY       Teton County            23,377            23,622
# 3201    WY       Uinta County            20,457            20,655
# 3202    WY    Washakie County             7,658             7,712
# 3203    WY      Weston County             6,818             6,766
#
#      POP_ESTIMATE_2022
# 2               59,759
# 3              246,435
# 4               24,706
# 5               22,005
# 6               59,512
# ...                ...
# 3199            41,345
# 3200            23,287
# 3201            20,712
# 3202             7,719
# 3203             6,860
#
# [3136 rows x 5 columns]

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3136 entries, 2 to 3203
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   State              3136 non-null   object
#  1   Area_Name          3136 non-null   object
#  2   POP_ESTIMATE_2020  3128 non-null   object
#  3   POP_ESTIMATE_2021  3128 non-null   object
#  4   POP_ESTIMATE_2022  3128 non-null   object
# dtypes: object(5)
# memory usage: 147.0+ KB

# %%
population[population.isna().any(axis=1)]
# Out:
#     State          Area_Name POP_ESTIMATE_2020 POP_ESTIMATE_2021  \
# 317    CT   Fairfield County               NaN               NaN
# 318    CT    Hartford County               NaN               NaN
# 319    CT  Litchfield County               NaN               NaN
# 320    CT   Middlesex County               NaN               NaN
# 321    CT   New Haven County               NaN               NaN
# 322    CT  New London County               NaN               NaN
# 323    CT     Tolland County               NaN               NaN
# 324    CT     Windham County               NaN               NaN
#
#     POP_ESTIMATE_2022
# 317               NaN
# 318               NaN
# 319               NaN
# 320               NaN
# 321               NaN
# 322               NaN
# 323               NaN
# 324               NaN

# %% [markdown]
# We don't want to exclude all of Connecticut so we will manually enter the population from a different source.
#
# Source: https://portal.ct.gov/DPH/Health-Information-Systems--Reporting/Population/Annual-Town-and-County-Population-for-Connecticut

# %%
population.loc[population[population['Area_Name'] == 'Fairfield County'].index[0], ['POP_ESTIMATE_2020', 'POP_ESTIMATE_2021', 'POP_ESTIMATE_2022']] = [957050, 959768, 956446]
population.loc[population[population['Area_Name'] == 'Hartford County'].index[0], ['POP_ESTIMATE_2020', 'POP_ESTIMATE_2021', 'POP_ESTIMATE_2022']] = [898682, 896854, 898636]
population.loc[population[population['Area_Name'] == 'Litchfield County'].index[0], ['POP_ESTIMATE_2020', 'POP_ESTIMATE_2021', 'POP_ESTIMATE_2022']] = [184938, 185000, 185175]
population.loc[population[population['Area_Name'] == 'Middlesex County'].index[0], ['POP_ESTIMATE_2020', 'POP_ESTIMATE_2021', 'POP_ESTIMATE_2022']] = [164063, 164759, 164568]
population.loc[population[population['Area_Name'] == 'New Haven County'].index[0], ['POP_ESTIMATE_2020', 'POP_ESTIMATE_2021', 'POP_ESTIMATE_2022']] = [864094, 863700, 864751]
population.loc[population[population['Area_Name'] == 'New London County'].index[0], ['POP_ESTIMATE_2020', 'POP_ESTIMATE_2021', 'POP_ESTIMATE_2022']] = [268450, 268805, 269131]
population.loc[population[population['Area_Name'] == 'Tolland County'].index[0], ['POP_ESTIMATE_2020', 'POP_ESTIMATE_2021', 'POP_ESTIMATE_2022']] = [149767, 150293, 150120]
population.loc[population[population['Area_Name'] == 'Windham County'].index[0], ['POP_ESTIMATE_2020', 'POP_ESTIMATE_2021', 'POP_ESTIMATE_2022']] = [116404, 116418, 116503]

population[population['State'] == 'CT']
# Drop the rows with NaN entirely
#population = population.dropna()
#population[population.isna().any(axis=1)]
# Out:
#     State          Area_Name POP_ESTIMATE_2020 POP_ESTIMATE_2021  \
# 317    CT   Fairfield County            957050            959768
# 318    CT    Hartford County            898682            896854
# 319    CT  Litchfield County            184938            185000
# 320    CT   Middlesex County            164063            164759
# 321    CT   New Haven County            864094            863700
# 322    CT  New London County            268450            268805
# 323    CT     Tolland County            149767            150293
# 324    CT     Windham County            116404            116418
#
#     POP_ESTIMATE_2022
# 317            956446
# 318            898636
# 319            185175
# 320            164568
# 321            864751
# 322            269131
# 323            150120
# 324            116503

# %% [markdown]
# Finally, apply same steps to poverty df

# %%
poverty.dropna(subset = ['Rural-urban_Continuum_Code_2003'], inplace=True)
poverty = poverty[['State','Area_name','POVALL_2021']]
# Drop PR State data
poverty = poverty[poverty['State'] != 'PR']
poverty
# Out:
#      State          Area_name  POVALL_2021
# 2       AL     Autauga County       6296.0
# 3       AL     Baldwin County      25526.0
# 4       AL     Barbour County       5089.0
# 5       AL        Bibb County       4204.0
# 6       AL      Blount County       6992.0
# ...    ...                ...          ...
# 3190    WY  Sweetwater County       3761.0
# 3191    WY       Teton County       1392.0
# 3192    WY       Uinta County       1917.0
# 3193    WY    Washakie County        773.0
# 3194    WY      Weston County        666.0
#
# [3136 rows x 3 columns]

# %%
poverty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3136 entries, 2 to 3194
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   State        3136 non-null   object
#  1   Area_name    3136 non-null   object
#  2   POVALL_2021  3135 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 98.0+ KB

# %%
poverty[poverty.isna().any(axis=1)]
# Out:
#     State       Area_name  POVALL_2021
# 562    HI  Kalawao County          NaN

# %%
# Drop the rows with NaN entirely
poverty = poverty.dropna()
poverty[poverty.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [State, Area_name, POVALL_2021]
# Index: []

# %% [markdown]
# We can now look at demographics

# %%
demographics.head()
# Out:
#            GEO_ID                     NAME                  P6_001N  \
# 0       Geography     Geographic Area Name   !!Total races tallied:
# 1  0500000US01001  Autauga County, Alabama                    62152
# 2  0500000US01003  Baldwin County, Alabama                   247467
# 3  0500000US01005  Barbour County, Alabama                    25973
# 4  0500000US01007     Bibb County, Alabama                    23121
#
#                                 P6_001NA  \
# 0  Annotation of  !!Total races tallied:
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                                              P6_002N  \
# 0   !!Total races tallied:!!White alone or in com...
# 1                                              45084
# 2                                             203968
# 3                                              11939
# 4                                              17275
#
#                                             P6_002NA  \
# 0  Annotation of  !!Total races tallied:!!White a...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              P6_003N  \
# 0   !!Total races tallied:!!Black or African Amer...
# 1                                              12266
# 2                                              20913
# 3                                              12261
# 4                                               4643
#
#                                             P6_003NA  \
# 0  Annotation of  !!Total races tallied:!!Black o...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              P6_004N  \
# 0   !!Total races tallied:!!American Indian and A...
# 1                                               1426
# 2                                               6961
# 3                                                362
# 4                                                430
#
#                                             P6_004NA  \
# 0  Annotation of  !!Total races tallied:!!America...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              P6_005N  \
# 0   !!Total races tallied:!!Asian alone or in com...
# 1                                               1360
# 2                                               3498
# 3                                                152
# 4                                                 56
#
#                                             P6_005NA  \
# 0  Annotation of  !!Total races tallied:!!Asian a...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              P6_006N  \
# 0   !!Total races tallied:!!Native Hawaiian and O...
# 1                                                115
# 2                                                354
# 3                                                 13
# 4                                                 18
#
#                                             P6_006NA  \
# 0  Annotation of  !!Total races tallied:!!Native ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              P6_007N  \
# 0   !!Total races tallied:!!Some Other Race alone...
# 1                                               1901
# 2                                              11773
# 3                                               1246
# 4                                                699
#
#                                             P6_007NA  Unnamed: 16
# 0  Annotation of  !!Total races tallied:!!Some Ot...          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4                                                NaN          NaN

# %% [markdown]
# We need to split the name column into a county and state as well as convert our columns from totals to percentages while renaming the columns as well.

# %%
demographics[['Name', 'State']] = demographics['NAME'].str.split(', ', expand=True)
demographics = demographics.iloc[1:]
demographics[['P6_001N', 'P6_002N', 'P6_003N', 'P6_004N', 'P6_005N', 'P6_006N']] = demographics[['P6_001N', 'P6_002N', 'P6_003N', 'P6_004N', 'P6_005N', 'P6_006N']].astype(int)
demographics[['P6_002N', 'P6_003N', 'P6_004N', 'P6_005N', 'P6_006N']] = demographics[['P6_002N', 'P6_003N', 'P6_004N', 'P6_005N', 'P6_006N']].div(demographics['P6_001N'], axis=0) * 100
# df[['A', 'B', 'C']] = df[['A', 'B', 'C']].div(df['D'], axis=0)
demographics = demographics[['Name', 'State', 'P6_002N', 'P6_003N', 'P6_004N', 'P6_005N', 'P6_006N']]

demographics.rename(columns={'P6_002N': 'Percent Caucasian','P6_003N':'Percent African American','P6_004N':'Percent Indian',
                             'P6_005N':'Percent Asian', 'P6_006N':'Percent Pacific'},inplace=True)

demographics.head()
# Out:
#              Name    State  Percent Caucasian  Percent African American  \
# 1  Autauga County  Alabama          72.538293                 19.735487
# 2  Baldwin County  Alabama          82.422303                  8.450824
# 3  Barbour County  Alabama          45.966966                 47.206715
# 4     Bibb County  Alabama          74.715626                 20.081311
# 5   Blount County  Alabama          86.188161                  1.985829
#
#    Percent Indian  Percent Asian  Percent Pacific
# 1        2.294375       2.188184         0.185030
# 2        2.812900       1.413522         0.143049
# 3        1.393755       0.585223         0.050052
# 4        1.859781       0.242204         0.077851
# 5        2.900899       0.568741         0.104852

# %% [markdown]
# Now we merge all data sources together. We need to convert our state column from abbreviated state labels to actual state names.

# %%
county_stats = pd.merge(population, education, left_on=['State', 'Area_Name'], right_on=['State', 'Area name'])
county_stats = pd.merge(county_stats, poverty, left_on=['State', 'Area name'], right_on=['State', 'Area_name'])
#county_stats = pd.merge(county_stats, demographics, left_on=['State', 'Area name'], right_on=['State', 'Name'])
states = {
        'AL': 'Alabama',
        'AK': 'Alaska',
        'AZ': 'Arizona',
        'AR': 'Arkansas',
        'CA': 'California',
        'CO': 'Colorado',
        'CT': 'Connecticut',
        'DE': 'Delaware',
        'DC': 'District of Columbia',
        'FL': 'Florida',
        'GA': 'Georgia',
        'HI': 'Hawaii',
        'ID': 'Idaho',
        'IL': 'Illinois',
        'IN': 'Indiana',
        'IA': 'Iowa',
        'KS': 'Kansas',
        'KY': 'Kentucky',
        'LA': 'Louisiana',
        'ME': 'Maine',
        'MD': 'Maryland',
        'MA': 'Massachusetts',
        'MI': 'Michigan',
        'MN': 'Minnesota',
        'MS': 'Mississippi',
        'MO': 'Missouri',
        'MT': 'Montana',
        'NE': 'Nebraska',
        'NV': 'Nevada',
        'NH': 'New Hampshire',
        'NJ': 'New Jersey',
        'NM': 'New Mexico',
        'NY': 'New York',
        'NC': 'North Carolina',
        'ND': 'North Dakota',
        'OH': 'Ohio',
        'OK': 'Oklahoma',
        'OR': 'Oregon',
        'PA': 'Pennsylvania',
        'RI': 'Rhode Island',
        'SC': 'South Carolina',
        'SD': 'South Dakota',
        'TN': 'Tennessee',
        'TX': 'Texas',
        'UT': 'Utah',
        'VT': 'Vermont',
        'VA': 'Virginia',
        'WA': 'Washington',
        'WV': 'West Virginia',
        'WI': 'Wisconsin',
        'WY': 'Wyoming',
      }
county_stats['State'] = county_stats['State'].replace(states)

county_stats = pd.merge(county_stats, demographics, left_on=['State', 'Area name'], right_on=['State', 'Name'])
county_stats
# Out:
#         State          Area_Name POP_ESTIMATE_2020 POP_ESTIMATE_2021  \
# 0     Alabama     Autauga County            58,902            59,210
# 1     Alabama     Baldwin County           233,219           239,361
# 2     Alabama     Barbour County            24,960            24,539
# 3     Alabama        Bibb County            22,183            22,370
# 4     Alabama      Blount County            59,102            59,085
# ...       ...                ...               ...               ...
# 3116  Wyoming  Sweetwater County            42,190            41,582
# 3117  Wyoming       Teton County            23,377            23,622
# 3118  Wyoming       Uinta County            20,457            20,655
# 3119  Wyoming    Washakie County             7,658             7,712
# 3120  Wyoming      Weston County             6,818             6,766
#
#      POP_ESTIMATE_2022          Area name  \
# 0               59,759     Autauga County
# 1              246,435     Baldwin County
# 2               24,706     Barbour County
# 3               22,005        Bibb County
# 4               59,512      Blount County
# ...                ...                ...
# 3116            41,345  Sweetwater County
# 3117            23,287       Teton County
# 3118            20,712       Uinta County
# 3119             7,719    Washakie County
# 3120             6,860      Weston County
#
#      Less than a high school diploma, 2017-21  \
# 0                                       4,126
# 1                                      14,555
# 2                                       4,378
# 3                                       3,125
# 4                                       6,650
# ...                                       ...
# 3116                                    2,029
# 3117                                      701
# 3118                                      851
# 3119                                      320
# 3120                                      348
#
#      High school diploma only, 2017-21  \
# 0                               12,977
# 1                               44,342
# 2                                6,600
# 3                                7,052
# 4                               14,284
# ...                                ...
# 3116                             9,069
# 3117                             2,984
# 3118                             4,820
# 3119                             1,391
# 3120                             1,826
#
#      Some college or associate's degree, 2017-21  \
# 0                                         11,367
# 1                                         50,518
# 2                                          5,010
# 3                                          3,967
# 4                                         13,673
# ...                                          ...
# 3116                                      11,324
# 3117                                       3,755
# 3118                                       5,186
# 3119                                       2,293
# 3120                                       1,818
#
#      Bachelor's degree or higher, 2017-21  ...  \
# 0                                  11,144  ...
# 1                                  52,562  ...
# 2                                   2,007  ...
# 3                                   1,913  ...
# 4                                   6,061  ...
# ...                                   ...  ...
# 3116                                5,394  ...
# 3117                               10,219  ...
# 3118                                2,376  ...
# 3119                                1,419  ...
# 3120                                  900  ...
#
#       Percent of adults completing some college or associate's degree, 2017-21  \
# 0                                                  28.7
# 1                                                  31.2
# 2                                                  27.8
# 3                                                  24.7
# 4                                                  33.6
# ...                                                 ...
# 3116                                               40.7
# 3117                                               21.3
# 3118                                               39.2
# 3119                                               42.3
# 3120                                               37.2
#
#       Percent of adults with a bachelor's degree or higher, 2017-21  \
# 0                                                  28.1
# 1                                                  32.5
# 2                                                  11.2
# 3                                                  11.9
# 4                                                  14.9
# ...                                                 ...
# 3116                                               19.4
# 3117                                               57.9
# 3118                                               18.0
# 3119                                               26.2
# 3120                                               18.4
#
#               Area_name  POVALL_2021               Name  Percent Caucasian  \
# 0        Autauga County       6296.0     Autauga County          72.538293
# 1        Baldwin County      25526.0     Baldwin County          82.422303
# 2        Barbour County       5089.0     Barbour County          45.966966
# 3           Bibb County       4204.0        Bibb County          74.715626
# 4         Blount County       6992.0      Blount County          86.188161
# ...                 ...          ...                ...                ...
# 3116  Sweetwater County       3761.0  Sweetwater County          82.504071
# 3117       Teton County       1392.0       Teton County          83.373748
# 3118       Uinta County       1917.0       Uinta County          88.286004
# 3119    Washakie County        773.0    Washakie County          86.147916
# 3120      Weston County        666.0      Weston County          90.180055
#
#      Percent African American  Percent Indian  Percent Asian  Percent Pacific
# 0                   19.735487        2.294375       2.188184         0.185030
# 1                    8.450824        2.812900       1.413522         0.143049
# 2                   47.206715        1.393755       0.585223         0.050052
# 3                   20.081311        1.859781       0.242204         0.077851
# 4                    1.985829        2.900899       0.568741         0.104852
# ...                       ...             ...            ...              ...
# 3116                 1.429245        3.167052       1.317819         0.370704
# 3117                 0.500626        1.630945       2.303661         0.140801
# 3118                 0.783699        2.825927       1.000369         0.368800
# 3119                 0.602265        2.372922       0.831125         0.192725
# 3120                 0.914127        3.781163       0.914127         0.304709
#
# [3121 rows x 22 columns]

# %% [markdown]
# Rename columns for clarity

# %%
county_stats.drop(columns=['Area name', 'Area_name', 'Name'], inplace=True)
county_stats.rename(columns={'State': 'state','Area_Name':'county','POP_ESTIMATE_2020':'pop_2020',
                             'POP_ESTIMATE_2021':'pop_2021', 'POP_ESTIMATE_2022':'pop_2022',
                             'Less than a high school diploma, 2017-21':'Less than a high school diploma',
                             'High school diploma only, 2017-21':'High school diploma only',
                             'Some college or associate\'s degree, 2017-21':'Some college or associate\'s degree',
                             'Bachelor\'s degree or higher, 2017-21':'Bachelor\'s degree or higher',
                             'Percent of adults with less than a high school diploma, 2017-21':'Percent of adults with less than a high school diploma',
                             'Percent of adults with a high school diploma only, 2017-21':'Percent of adults with a high school diploma only',
                             'Percent of adults completing some college or associate\'s degree, 2017-21':'Percent of adults completing some college or associate\'s degree',
                             'Percent of adults with a bachelor\'s degree or higher, 2017-21':'Percent of adults with a bachelor\'s degree or higher',
                             'POVALL_2021':'pov_2021'},inplace=True)


county_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3121 entries, 0 to 3120
# Data columns (total 19 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   state                                                            3121 non-null   object
#  1   county                                                           3121 non-null   object
#  2   pop_2020                                                         3121 non-null   object
#  3   pop_2021                                                         3121 non-null   object
#  4   pop_2022                                                         3121 non-null   object
#  5   Less than a high school diploma                                  3121 non-null   object
#  6   High school diploma only                                         3121 non-null   object
#  7   Some college or associate's degree                               3121 non-null   object
#  8   Bachelor's degree or higher                                      3121 non-null   object
#  9   Percent of adults with less than a high school diploma           3121 non-null   float64
#  10  Percent of adults with a high school diploma only                3121 non-null   float64
#  11  Percent of adults completing some college or associate's degree  3121 non-null   float64
#  12  Percent of adults with a bachelor's degree or higher             3121 non-null   float64
#  13  pov_2021                                                         3121 non-null   float64
#  14  Percent Caucasian                                                3121 non-null   float64
#  15  Percent African American                                         3121 non-null   float64
#  16  Percent Indian                                                   3121 non-null   float64
#  17  Percent Asian                                                    3121 non-null   float64
#  18  Percent Pacific                                                  3121 non-null   float64
# dtypes: float64(10), object(9)
# memory usage: 487.7+ KB

# %%
# Remove names that do not match between county_data and county_stats
# First fix names from county_stats to find better matches
county_stats['county'] = county_stats['county'].str.replace(' County', '')
county_stats['county'] = county_stats['county'].str.replace(' Parish', '')
county_stats['county'] = county_stats['county'].str.replace(' Borough', '')
# and fix county_data
county_data['county'] = county_data['county'].str.replace(' Borough', '')
county_data['county'] = county_data['county'].str.replace('New York City', 'New York')


county_stats.info()
county_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3121 entries, 0 to 3120
# Data columns (total 19 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   state                                                            3121 non-null   object
#  1   county                                                           3121 non-null   object
#  2   pop_2020                                                         3121 non-null   object
#  3   pop_2021                                                         3121 non-null   object
#  4   pop_2022                                                         3121 non-null   object
#  5   Less than a high school diploma                                  3121 non-null   object
#  6   High school diploma only                                         3121 non-null   object
#  7   Some college or associate's degree                               3121 non-null   object
#  8   Bachelor's degree or higher                                      3121 non-null   object
#  9   Percent of adults with less than a high school diploma           3121 non-null   float64
#  10  Percent of adults with a high school diploma only                3121 non-null   float64
#  11  Percent of adults completing some college or associate's degree  3121 non-null   float64
#  12  Percent of adults with a bachelor's degree or higher             3121 non-null   float64
#  13  pov_2021                                                         3121 non-null   float64
#  14  Percent Caucasian                                                3121 non-null   float64
#  15  Percent African American                                         3121 non-null   float64
#  16  Percent Indian                                                   3121 non-null   float64
#  17  Percent Asian                                                    3121 non-null   float64
#  18  Percent Pacific                                                  3121 non-null   float64
# dtypes: float64(10), object(9)
# memory usage: 487.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2420070 entries, 0 to 2502831
# Data columns (total 7 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   date           datetime64[ns]
#  1   county         object
#  2   state          object
#  3   cases          int64
#  4   deaths         int64
#  5   cases_change   int64
#  6   deaths_change  int64
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 147.7+ MB

# %%
stat_strings = county_stats['county'].unique()
data_strings = county_data['county'].unique()
matches1 = [str1 for str1 in stat_strings for str2 in data_strings if str2 in str1]
matches2 = [str1 for str1 in data_strings for str2 in stat_strings if str2 in str1]
county_stats = county_stats[county_stats['county'].str.contains('|'.join(matches1))]
county_data = county_data[county_data['county'].str.contains('|'.join(matches2))]
county_stats.info()
county_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3119 entries, 0 to 3120
# Data columns (total 19 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   state                                                            3119 non-null   object
#  1   county                                                           3119 non-null   object
#  2   pop_2020                                                         3119 non-null   object
#  3   pop_2021                                                         3119 non-null   object
#  4   pop_2022                                                         3119 non-null   object
#  5   Less than a high school diploma                                  3119 non-null   object
#  6   High school diploma only                                         3119 non-null   object
#  7   Some college or associate's degree                               3119 non-null   object
#  8   Bachelor's degree or higher                                      3119 non-null   object
#  9   Percent of adults with less than a high school diploma           3119 non-null   float64
#  10  Percent of adults with a high school diploma only                3119 non-null   float64
#  11  Percent of adults completing some college or associate's degree  3119 non-null   float64
#  12  Percent of adults with a bachelor's degree or higher             3119 non-null   float64
#  13  pov_2021                                                         3119 non-null   float64
#  14  Percent Caucasian                                                3119 non-null   float64
#  15  Percent African American                                         3119 non-null   float64
#  16  Percent Indian                                                   3119 non-null   float64
#  17  Percent Asian                                                    3119 non-null   float64
#  18  Percent Pacific                                                  3119 non-null   float64
# dtypes: float64(10), object(9)
# memory usage: 487.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2407167 entries, 0 to 2502831
# Data columns (total 7 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   date           datetime64[ns]
#  1   county         object
#  2   state          object
#  3   cases          int64
#  4   deaths         int64
#  5   cases_change   int64
#  6   deaths_change  int64
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 146.9+ MB

# %% [markdown]
# The last step we want to do is fix our column types.

# %%
county_stats[['pop_2020', 'pop_2021', 'pop_2022', 'Less than a high school diploma', 'High school diploma only', 'Some college or associate\'s degree', 'Bachelor\'s degree or higher']] = county_stats[['pop_2020', 'pop_2021', 'pop_2022', 'Less than a high school diploma', 'High school diploma only', 'Some college or associate\'s degree', 'Bachelor\'s degree or higher']].astype(str).replace(',', '', regex=True).astype(int)
county_stats.head()
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_5956\599054344.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   county_stats[['pop_2020', 'pop_2021', 'pop_2022', 'Less than a high school diploma', 'High school diploma only', 'Some college or associate\'s degree', 'Bachelor\'s degree or higher']] = county_stats[['pop_2020', 'pop_2021', 'pop_2022', 'Less than a high school diploma', 'High school diploma only', 'Some college or associate\'s degree', 'Bachelor\'s degree or higher']].astype(str).replace(',', '', regex=True).astype(int)
#      state   county  pop_2020  pop_2021  pop_2022  \
# 0  Alabama  Autauga     58902     59210     59759
# 1  Alabama  Baldwin    233219    239361    246435
# 2  Alabama  Barbour     24960     24539     24706
# 3  Alabama     Bibb     22183     22370     22005
# 4  Alabama   Blount     59102     59085     59512
#
#    Less than a high school diploma  High school diploma only  \
# 0                             4126                     12977
# 1                            14555                     44342
# 2                             4378                      6600
# 3                             3125                      7052
# 4                             6650                     14284
#
#    Some college or associate's degree  Bachelor's degree or higher  \
# 0                               11367                        11144
# 1                               50518                        52562
# 2                                5010                         2007
# 3                                3967                         1913
# 4                               13673                         6061
#
#    Percent of adults with less than a high school diploma  \
# 0                                               10.4
# 1                                                9.0
# 2                                               24.3
# 3                                               19.5
# 4                                               16.4
#
#    Percent of adults with a high school diploma only  \
# 0                                               32.8
# 1                                               27.4
# 2                                               36.7
# 3                                               43.9
# 4                                               35.1
#
#    Percent of adults completing some college or associate's degree  \
# 0                                               28.7
# 1                                               31.2
# 2                                               27.8
# 3                                               24.7
# 4                                               33.6
#
#    Percent of adults with a bachelor's degree or higher  pov_2021  \
# 0                                               28.1       6296.0
# 1                                               32.5      25526.0
# 2                                               11.2       5089.0
# 3                                               11.9       4204.0
# 4                                               14.9       6992.0
#
#    Percent Caucasian  Percent African American  Percent Indian  Percent Asian  \
# 0          72.538293                 19.735487        2.294375       2.188184
# 1          82.422303                  8.450824        2.812900       1.413522
# 2          45.966966                 47.206715        1.393755       0.585223
# 3          74.715626                 20.081311        1.859781       0.242204
# 4          86.188161                  1.985829        2.900899       0.568741
#
#    Percent Pacific
# 0         0.185030
# 1         0.143049
# 2         0.050052
# 3         0.077851
# 4         0.104852

# %% [markdown]
# We want to also add density and average house size

# %%
# ADD ANOTHER FILE
county_density = pd.read_csv('../data/Average_Household_Size_and_Population_Density_-_County.csv')
county_density = county_density[['State', 'NAME', 'B25010_001E', 'B01001_calc_PopDensity']]
county_density = county_density.rename(columns={'State': 'state', 'NAME': 'county', 'B25010_001E': 'avg_house_size', 'B01001_calc_PopDensity': 'pop_density'})

# MERGE
county_stats = county_stats.loc[county_stats['county'] != 'Bristol Bay']
county_stats = county_stats.loc[county_stats['county'] != 'Lake and Peninsula']
index_drop = county_stats[(county_stats['state'] == 'New York') & ((county_stats['county'] == 'Richmond') | (county_stats['county'] == 'Kings'))].index
county_stats.drop(index_drop , inplace=True)

county_density['county'] = county_density['county'].str.replace(' County', '')
county_density['county'] = county_density['county'].str.replace(' Borough', '')
county_density['county'] = county_density['county'].str.replace(' Parish', '')

county_stats = pd.merge(county_stats, county_density, how='inner', left_on=['state', 'county'], right_on=['state','county'])
county_stats.head()
# Out:
#      state   county  pop_2020  pop_2021  pop_2022  \
# 0  Alabama  Autauga     58902     59210     59759
# 1  Alabama  Baldwin    233219    239361    246435
# 2  Alabama  Barbour     24960     24539     24706
# 3  Alabama     Bibb     22183     22370     22005
# 4  Alabama   Blount     59102     59085     59512
#
#    Less than a high school diploma  High school diploma only  \
# 0                             4126                     12977
# 1                            14555                     44342
# 2                             4378                      6600
# 3                             3125                      7052
# 4                             6650                     14284
#
#    Some college or associate's degree  Bachelor's degree or higher  \
# 0                               11367                        11144
# 1                               50518                        52562
# 2                                5010                         2007
# 3                                3967                         1913
# 4                               13673                         6061
#
#    Percent of adults with less than a high school diploma  ...  \
# 0                                               10.4       ...
# 1                                                9.0       ...
# 2                                               24.3       ...
# 3                                               19.5       ...
# 4                                               16.4       ...
#
#    Percent of adults completing some college or associate's degree  \
# 0                                               28.7
# 1                                               31.2
# 2                                               27.8
# 3                                               24.7
# 4                                               33.6
#
#    Percent of adults with a bachelor's degree or higher  pov_2021  \
# 0                                               28.1       6296.0
# 1                                               32.5      25526.0
# 2                                               11.2       5089.0
# 3                                               11.9       4204.0
# 4                                               14.9       6992.0
#
#    Percent Caucasian  Percent African American  Percent Indian  Percent Asian  \
# 0          72.538293                 19.735487        2.294375       2.188184
# 1          82.422303                  8.450824        2.812900       1.413522
# 2          45.966966                 47.206715        1.393755       0.585223
# 3          74.715626                 20.081311        1.859781       0.242204
# 4          86.188161                  1.985829        2.900899       0.568741
#
#    Percent Pacific  avg_house_size  pop_density
# 0         0.185030            2.59    35.853419
# 1         0.143049            2.61    50.541504
# 2         0.050052            2.49    11.247981
# 3         0.077851            2.99    13.973114
# 4         0.104852            2.77    34.515816
#
# [5 rows x 21 columns]

# %% [markdown]
# We want to also manually edit the NYC

# %%
county_stats.loc[county_stats[county_stats['county'] == 'New York'].index[0], ['pop_2020', 'pop_2021', 'pop_2022', 'pop_density']] = [8772978, 8467513, 8495691, 11234]
county_stats[county_stats['county'] == 'New York']
# Out:
#          state    county  pop_2020  pop_2021  pop_2022  \
# 1836  New York  New York   8772978   8467513   8495691
#
#       Less than a high school diploma  High school diploma only  \
# 1836                           148767                    156704
#
#       Some college or associate's degree  Bachelor's degree or higher  \
# 1836                              174128                       801081
#
#       Percent of adults with less than a high school diploma  ...  \
# 1836                                               11.6       ...
#
#       Percent of adults completing some college or associate's degree  \
# 1836                                               13.6
#
#       Percent of adults with a bachelor's degree or higher  pov_2021  \
# 1836                                               62.6     264938.0
#
#       Percent Caucasian  Percent African American  Percent Indian  \
# 1836          52.209472                 15.119599        1.426146
#
#       Percent Asian  Percent Pacific  avg_house_size  pop_density
# 1836       13.48569         0.289279            2.07      11234.0
#
# [1 rows x 21 columns]

# %% [markdown]
# Save data for Exploratory Data Analysis

# %%
datapath = '../data'
save_file(county_data, 'county_data_cleaned.csv', datapath)
save_file(county_stats, 'county_stats_cleaned.csv', datapath)
# Out:
# A file already exists with this name.
#
# Do you want to overwrite? (Y/N)Y
# Writing file.  "../data\county_data_cleaned.csv"
# A file already exists with this name.
#
# Do you want to overwrite? (Y/N)Y
# Writing file.  "../data\county_stats_cleaned.csv"
